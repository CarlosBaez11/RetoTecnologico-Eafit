# %% [markdown]
# <a href="https://colab.research.google.com/github/CarlosBaez11/RetoTecnologico-Eafit/blob/main/Copia_de_Copia_de_ProyectoTecnologico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import sklearn
import matplotlib as plt
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#import sweetviz as sv

# %%
# !git clone https://github.com/CarlosBaez11/RetoTecnologico-Eafit.git
# Out:
# Cloning into 'RetoTecnologico-Eafit'...
# remote: Enumerating objects: 90, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 90 (delta 5), reused 11 (delta 3), pack-reused 73
# Receiving objects: 100% (90/90), 74.22 MiB | 39.08 MiB/s, done.
# Resolving deltas: 100% (39/39), done.

# %%
data=pd.read_excel("/content/RetoTecnologico-Eafit/Caso 01 - Cobranza Sector Financiero.xlsx")

# %%
data.head(5)
# Out:
#    Consecutivo Documento Deudor  Nit  Nombres  Numero Documento  \
# 0                      28768192   18      NaN               NaN
# 1                       2712044   22      NaN               NaN
# 2                      13587837   23      NaN               NaN
# 3                      23479925   46      NaN               NaN
# 4                       2712382   92      NaN               NaN
#
#    Tipo De Producto             PRODUCTO  Valor Obligacion  Valor Vencido  \
# 0                 3  TARJETAS DE CREDITO         5637605.0       152093.0
# 1                 5              CONSUMO           40584.0        40584.0
# 2                 3  TARJETAS DE CREDITO         2786178.0       547088.0
# 3                 3  TARJETAS DE CREDITO         5904653.0      1455631.0
# 4                 5              CONSUMO         2221125.0      2221125.0
#
#    Regional  REGION  ...  Red                                  Cuadrante  \
# 0      2099  BOGOTA  ...    1  TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA
# 1      2099  BOGOTA  ...    1                              SIN CUADRANTE
# 2      3099     SUR  ...    1  TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA
# 3      2099  BOGOTA  ...    1        NO TIENE VOLUNTAD Y TIENE CAPACIDAD
# 4      6399  CENTRO  ...    1           TIENE VOLUNTAD Y TIENE CAPACIDAD
#
#            Descripcion Causal Calificacion Real Fecha De Perfeccionamiento  \
# 0                   CALAMIDAD                 2                 1978-12-06
# 1          SIN CAUSAL DE MORA                 3                 2015-03-11
# 2  RETRASO EN PAGO DE SALARIO                 1                 2003-03-27
# 3                    DESCUIDO                 1                 1990-09-01
# 4                    DESCUIDO                 2                 2015-05-12
#
#   Endeudamiento  Rango endeudamiento  Sector Economico      Profesion  \
# 0     5637605.0               1 a 15               NaN  SIN PROFESION
# 1       40584.0                  <1M               NaN  SIN PROFESION
# 2     7747280.0               1 a 15               NaN  SIN PROFESION
# 3     5904653.0               1 a 15               NaN  SIN PROFESION
# 4     2221125.0               1 a 15      AGROPECUARIO     AGRICULTOR
#
#     Ocupacion
# 0  SIN OFICIO
# 1  SIN OFICIO
# 2    JUBILADO
# 3  SIN OFICIO
# 4     TAXISTA
#
# [5 rows x 27 columns]

# %%
my_report=sv.analyze(V_categ)
my_report.show_html()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
my_report.show_notebook()
# Out:
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# !function(e,t){&quot;use strict&quot;;&quot;object&quot;==typeof module&amp;&amp;&quot;object&quot;==typeof module.exports?module.exports=e.document?t(e,!0):function(e){if(!e.document)throw new Error(&quot;jQuery requires a window with a document&quot;);return t(e)}:t(e)}(&quot;undefined&quot;!=typeof window?window:this,function(C,e){&quot;use strict&quot;;var t=[],E=C.document,r=Object.getPrototypeOf,s=t.slice,g=t.concat,u=t.push,i=t.indexOf,n={},o=n.toString,v=n.hasOwnProperty,a=v.toString,l=a.call(Object),y={},m=function(e){return&quot;function&quot;==typeof e&amp;&amp;&quot;number&quot;!=typeof e.nodeType},x=function(e){return null!=e&amp;&amp;e===e.window},c={type:!0,src:!0,nonce:!0,noModule:!0};function b(e,t,n){var r,i,o=(n=n||E).createElement(&quot;script&quot;);if(o.text=e,t)for(r in c)(i=t[r]||t.getAttribute&amp;&amp;t.getAttribute(r))&amp;&amp;o.setAttribute(r,i);n.head.appendChild(o).parentNode.removeChild(o)}function w(e){return null==e?e+&quot;&quot;:&quot;object&quot;==typeof e||&quot;function&quot;==typeof e?n[o.call(e)]||&quot;object&quot;:typeof e}var f=&quot;3.4.1&quot;,k=function(e,t){return new k.fn.init(e,t)},p=/^[\s\uFEFF\xA0]+|[\s\uFEFF\xA0]+$/g;function d(e){var t=!!e&amp;&amp;&quot;length&quot;in e&amp;&amp;e.length,n=w(e);return!m(e)&amp;&amp;!x(e)&amp;&amp;(&quot;array&quot;===n||0===t||&quot;number&quot;==typeof t&amp;&amp;0&lt;t&amp;&amp;t-1 in e)}k.fn=k.prototype={jquery:f,constructor:k,length:0,toArray:function(){return s.call(this)},get:function(e){return null==e?s.call(this):e&lt;0?this[e+this.length]:this[e]},pushStack:function(e){var t=k.merge(this.constructor(),e);return t.prevObject=this,t},each:function(e){return k.each(this,e)},map:function(n){return this.pushStack(k.map(this,function(e,t){return n.call(e,t,e)}))},slice:function(){return this.pushStack(s.apply(this,arguments))},first:function(){return this.eq(0)},last:function(){return this.eq(-1)},eq:function(e){var t=this.length,n=+e+(e&lt;0?t:0);return this.pushStack(0&lt;=n&amp;&amp;n&lt;t?[this[n]]:[])},end:function(){return this.prevObject||this.constructor()},push:u,sort:t.sort,splice:t.splice},k.extend=k.fn.extend=function(){var e,t,n,r,i,o,a=arguments[0]||{},s=1,u=arguments.length,l=!1;for(&quot;boolean&quot;==typeof a&amp;&amp;(l=a,a=arguments[s]||{},s++),&quot;object&quot;==typeof a||m(a)||(a={}),s===u&amp;&amp;(a=this,s--);s&lt;u;s++)if(null!=(e=arguments[s]))for(t in e)r=e[t],&quot;__proto__&quot;!==t&amp;&amp;a!==r&amp;&amp;(l&amp;&amp;r&amp;&amp;(k.isPlainObject(r)||(i=Array.isArray(r)))?(n=a[t],o=i&amp;&amp;!Array.isArray(n)?[]:i||k.isPlainObject(n)?n:{},i=!1,a[t]=k.extend(l,o,r)):void 0!==r&amp;&amp;(a[t]=r));return a},k.extend({expando:&quot;jQuery&quot;+(f+Math.random()).replace(/\D/g,&quot;&quot;),isReady:!0,error:function(e){throw new Error(e)},noop:function(){},isPlainObject:function(e){var t,n;return!(!e||&quot;[object Object]&quot;!==o.call(e))&amp;&amp;(!(t=r(e))||&quot;function&quot;==typeof(n=v.call(t,&quot;constructor&quot;)&amp;&amp;t.constructor)&amp;&amp;a.call(n)===l)},isEmptyObject:function(e){var t;for(t in e)return!1;return!0},globalEval:function(e,t){b(e,{nonce:t&amp;&amp;t.nonce})},each:function(e,t){var n,r=0;if(d(e)){for(n=e.length;r&lt;n;r++)if(!1===t.call(e[r],r,e[r]))break}else for(r in e)if(!1===t.call(e[r],r,e[r]))break;return e},trim:function(e){return null==e?&quot;&quot;:(e+&quot;&quot;).replace(p,&quot;&quot;)},makeArray:function(e,t){var n=t||[];return null!=e&amp;&amp;(d(Object(e))?k.merge(n,&quot;string&quot;==typeof e?[e]:e):u.call(n,e)),n},inArray:function(e,t,n){return null==t?-1:i.call(t,e,n)},merge:function(e,t){for(var n=+t.length,r=0,i=e.length;r&lt;n;r++)e[i++]=t[r];return e.length=i,e},grep:function(e,t,n){for(var r=[],i=0,o=e.length,a=!n;i&lt;o;i++)!t(e[i],i)!==a&amp;&amp;r.push(e[i]);return r},map:function(e,t,n){var r,i,o=0,a=[];if(d(e))for(r=e.length;o&lt;r;o++)null!=(i=t(e[o],o,n))&amp;&amp;a.push(i);else for(o in e)null!=(i=t(e[o],o,n))&amp;&amp;a.push(i);return g.apply([] ...

# %%
print(data.columns)
print(data.dtypes)
print(data.shape)
V_categ=data[['Consecutivo Documento Deudor','Tipo De Producto','PRODUCTO','Regional','REGION','Abogado','FRANJA','Segmento','Oficina Radicacion','Red','Cuadrante','Descripcion Causal',
              'Calificacion Real', 'Profesion', 'Ocupacion']]
# Out:
# Index(['Consecutivo Documento Deudor', 'Nit', 'Nombres', 'Numero Documento',
#        'Tipo De Producto', 'PRODUCTO', 'Valor Obligacion', 'Valor Vencido',
#        'Regional', 'REGION', 'Abogado', 'Dias Mora', 'FRANJA',
#        'Fecha Traslado Para Cobro', 'Fecha Ultima Facturacion', 'Segmento',
#        'Oficina Radicacion', 'Red', 'Cuadrante', 'Descripcion Causal',
#        'Calificacion Real', 'Fecha De Perfeccionamiento', 'Endeudamiento',
#        'Rango endeudamiento', 'Sector Economico', 'Profesion', 'Ocupacion'],
#       dtype='object')
# Consecutivo Documento Deudor             int64
# Nit                                      int64
# Nombres                                float64
# Numero Documento                       float64
# Tipo De Producto                         int64
# PRODUCTO                                object
# Valor Obligacion                       float64
# Valor Vencido                          float64
# Regional                                 int64
# REGION                                  object
# Abogado                                  int64
# Dias Mora                                int64
# FRANJA                                  object
# Fecha Traslado Para Cobro       datetime64[ns]
# Fecha Ultima Facturacion        datetime64[ns]
# Segmento                                object
# Oficina Radicacion                       int64
# Red                                      int64
# Cuadrante                               object
# Descripcion Causal                      object
# Calificacion Real                        int64
# Fecha De Perfeccionamiento      datetime64[ns]
# Endeudamiento                          float64
# Rango endeudamiento                     object
# Sector Economico                        object
# Profesion                               object
# Ocupacion                               object
# dtype: object
# (89247, 27)

# %%
import missingno as msn
msn.bar(data)
# Out:
# <Axes: >

# %%
data.drop(columns="Nombres", axis=1, inplace=True)
data.drop(columns="Numero Documento", axis=1, inplace=True)
data.drop(columns="Sector Economico", axis=1, inplace=True)

# %%
data.dropna(inplace=True)

# %%
msn.bar(data)
# Out:
# <Axes: >

# %% [markdown]
# # Sección nueva

# %%
V_categ
# Out:
#        Consecutivo Documento Deudor  Tipo De Producto             PRODUCTO  \
# 0                          28768192                 3  TARJETAS DE CREDITO
# 1                           2712044                 5              CONSUMO
# 2                          13587837                 3  TARJETAS DE CREDITO
# 3                          23479925                 3  TARJETAS DE CREDITO
# 4                           2712382                 5              CONSUMO
# ...                             ...               ...                  ...
# 89242                      24892452                89              CONSUMO
# 89243                      24485118                 4              CONSUMO
# 89244                      27364653                88              CONSUMO
# 89245                      28482366                88              CONSUMO
# 89246                      27641335                88              CONSUMO
#
#        Regional  REGION  Abogado  FRANJA       Segmento  Oficina Radicacion  \
# 0          2099  BOGOTA   109978     <30  PERSONAL PLUS                  31
# 1          2099  BOGOTA   109976  91-120  PERSONAL PLUS                 461
# 2          3099     SUR   109978   31-60       PERSONAS                 813
# 3          2099  BOGOTA   109978   61-90          PYMES                 612
# 4          6399  CENTRO   109978   31-60  PERSONAL PLUS                  57
# ...         ...     ...      ...     ...            ...                 ...
# 89242      3099     SUR   109976  91-120  PERSONAL PLUS                 825
# 89243      3099     SUR   109976  91-120  PERSONAL PLUS                 812
# 89244      3099     SUR   109976  91-120  PERSONAL PLUS                 812
# 89245      3099     SUR   109976  91-120  PERSONAL PLUS                 812
# 89246      3099     SUR   109976  91-120  PERSONAL PLUS                 812
#
#        Red                                  Cuadrante  \
# 0        1  TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA
# 1        1                              SIN CUADRANTE
# 2        1  TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA
# 3        1        NO TIENE VOLUNTAD Y TIENE CAPACIDAD
# 4        1           TIENE VOLUNTAD Y TIENE CAPACIDAD
# ...    ...                                        ...
# 89242    1  TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA
# 89243    1        NO TIENE VOLUNTAD Y TIENE CAPACIDAD
# 89244    1        NO TIENE VOLUNTAD Y TIENE CAPACIDAD
# 89245    1        NO TIENE VOLUNTAD Y TIENE CAPACIDAD
# 89246    1        NO TIENE VOLUNTAD Y TIENE CAPACIDAD
#
#                       Descripcion Causal  Calificacion Real      Profesion  \
# 0                              CALAMIDAD                  2  SIN PROFESION
# 1                     SIN CAUSAL DE MORA                  3  SIN PROFESION
# 2             RETRASO EN PAGO DE SALARIO                  1  SIN PROFESION
# 3                               DESCUIDO                  1  SIN PROFESION
# 4                               DESCUIDO                  2     AGRICULTOR
# ...                                  ...                ...            ...
# 89242                           DESCUIDO                  3       PROFESOR
# 89243  DESEMPLEADO TITULAR Y/O COTITULAR                  3  SIN PROFESION
# 89244  DESEMPLEADO TITULAR Y/O COTITULAR                  3  SIN PROFESION
# 89245  DESEMPLEADO TITULAR Y/O COTITULAR                  3  SIN PROFESION
# 89246  DESEMPLEADO TITULAR Y/O COTITULAR                  3  SIN PROFESION
#
#                      Ocupacion
# 0                   SIN OFICIO
# 1                   SIN OFICIO
# 2                     JUBILADO
# 3                   SIN OFICIO
# 4                      TAXISTA
# ...                        ...
# 89242  EMPLEADO SECTOR PUBLICO
# 89243               SIN OFICIO
# 89244               SIN OFICIO
# 89245               SIN OFICIO
# 89246               SIN OFICIO
#
# [89247 rows x 15 columns]

# %%
V_num=data[['Valor Obligacion','Endeudamiento','Valor Vencido','Dias Mora']]
V_num
# Out:
#        Valor Obligacion  Endeudamiento  Valor Vencido  Dias Mora
# 0             5637605.0     5637605.00       152093.0         30
# 1               40584.0       40584.00        40584.0        110
# 2             2786178.0     7747280.00       547088.0         60
# 3             5904653.0     5904653.00      1455631.0         90
# 4             2221125.0     2221125.00      2221125.0         48
# ...                 ...            ...            ...        ...
# 89242         2048599.0    37088351.03       284377.0         95
# 89243        33835903.0    45757681.00      2790040.0        104
# 89244         1540300.0    45757681.00      1511822.0        107
# 89245         3954718.0    45757681.00       609495.0        107
# 89246         2172488.0    45757681.00       350295.0        107
#
# [78244 rows x 4 columns]

# %%
#data.drop(columns="Tipo De Producto", axis=1, inplace=True)

# %%
#data.drop(columns="Dias Mora", axis=1, inplace=True) #eliminamos esta columna y nos quedamos solo con franja ya que en esta ultima se encuentra implica
#el numero de dias de mora pero ya esta categorizado

# %% [markdown]
# #Tablas de contingencia
# a continuacion se observar como se relacianan algunas variables de interes frente a otras, esto a fin de identificar posibles relaciones entre pares de variables y asi mismo buscar rasgos caracteristicos que nos permitan identificar segmentos a los cuales podamosaplicar diferentes estrategia que sean mas adecuadas de acuerdo a sus caracteristicas

# %%
pd.crosstab(data['Rango endeudamiento'], data["PRODUCTO"], margins=True)/89062*100
# Out:
# PRODUCTO             CH PROPIA    CONSUMO  MASIVO SUFI  TARJETAS DE CREDITO  \
# Rango endeudamiento
# 1 a 15                0.000000  11.302239     2.135591            30.984034
# 100 a 200             0.000000   0.332353     0.002246             0.245896
# 15 a 50               0.000000   6.675125     0.309896             5.879051
# 50 a 100              0.001123   1.889695     0.015719             1.050953
# <1M                   0.000000   1.323797     0.443511            18.882352
# >200                  0.000000   0.140352     0.000000             0.048281
# All                   0.001123  21.663560     2.906964            57.090566
#
# PRODUCTO             VEHICULOS SUFI        All
# Rango endeudamiento
# 1 a 15                     2.485909  46.907772
# 100 a 200                  0.086457   0.666951
# 15 a 50                    3.133772  15.997844
# 50 a 100                   0.354809   3.312299
# <1M                        0.105544  20.755204
# >200                       0.024702   0.213335
# All                        6.191193  87.853405

# %%
pd.crosstab(data['Rango endeudamiento'], data["PRODUCTO"], margins=True)/89062*100
# Out:
# PRODUCTO             CH PROPIA    CONSUMO  MASIVO SUFI  TARJETAS DE CREDITO  \
# Rango endeudamiento
# 1 a 15                0.000000  11.302239     2.135591            30.984034
# 100 a 200             0.000000   0.332353     0.002246             0.245896
# 15 a 50               0.000000   6.675125     0.309896             5.879051
# 50 a 100              0.001123   1.889695     0.015719             1.050953
# <1M                   0.000000   1.323797     0.443511            18.882352
# >200                  0.000000   0.140352     0.000000             0.048281
# All                   0.001123  21.663560     2.906964            57.090566
#
# PRODUCTO             VEHICULOS SUFI        All
# Rango endeudamiento
# 1 a 15                     2.485909  46.907772
# 100 a 200                  0.086457   0.666951
# 15 a 50                    3.133772  15.997844
# 50 a 100                   0.354809   3.312299
# <1M                        0.105544  20.755204
# >200                       0.024702   0.213335
# All                        6.191193  87.853405

# %%
Obligacion_cuadrante=data.groupby(["Rango endeudamiento", "PRODUCTO"]).aggregate({"PRODUCTO":"count", "Valor Obligacion":"count"})
Obligacion_cuadrante.rename(columns=({"PRODUCTO":"Conteo Productos"}), inplace=True)
Obligacion_cuadrante.reset_index(inplace=True)
sns.barplot(Obligacion_cuadrante, x="Rango endeudamiento", y="Valor Obligacion", hue="PRODUCTO")
# Out:
# <Axes: xlabel='Rango endeudamiento', ylabel='Valor Obligacion'>

# %% [markdown]
# podemos observar que: las tarjetas de credito y los creditos de consumo son los productos cuyo valor de obligacion es mayor,
# especialmente las personas que poseen un rango de endeudameinto de 1 a 15 millones,

# %%
pd.crosstab(data['Rango endeudamiento'], data["Calificacion Real"], margins=True)/89062*100
# Out:
# Calificacion Real           0          1          2          3        All
# Rango endeudamiento
# 1 a 15               3.387528  16.582830  15.948440  10.988974  46.907772
# 100 a 200            0.136983   0.205475   0.269475   0.055018   0.666951
# 15 a 50              0.779232   5.096450   5.637646   4.484516  15.997844
# 50 a 100             0.335721   1.164357   1.157621   0.654600   3.312299
# <1M                  3.151737   5.920595   7.649727   4.033145  20.755204
# >200                 0.040421   0.098808   0.059509   0.014597   0.213335
# All                  7.831623  29.068514  30.722418  20.230850  87.853405

# %%
endeudamiento_cuadrante=data.groupby(["Rango endeudamiento", "Calificacion Real"]).aggregate({"Calificacion Real":"count", "Valor Obligacion":"count"})
endeudamiento_cuadrante.rename(columns=({"Calificacion Real":"Conteo Productos"}), inplace=True)
endeudamiento_cuadrante.reset_index(inplace=True)
sns.barplot(endeudamiento_cuadrante, x="Rango endeudamiento", y="Valor Obligacion", hue="Calificacion Real")
# Out:
# <Axes: xlabel='Rango endeudamiento', ylabel='Valor Obligacion'>

# %%
pd.crosstab(data['Rango endeudamiento'], data["Calificacion Real"], margins=True)/89062*100
# Out:
# Calificacion Real           0          1          2          3        All
# Rango endeudamiento
# 1 a 15               3.387528  16.582830  15.948440  10.988974  46.907772
# 100 a 200            0.136983   0.205475   0.269475   0.055018   0.666951
# 15 a 50              0.779232   5.096450   5.637646   4.484516  15.997844
# 50 a 100             0.335721   1.164357   1.157621   0.654600   3.312299
# <1M                  3.151737   5.920595   7.649727   4.033145  20.755204
# >200                 0.040421   0.098808   0.059509   0.014597   0.213335
# All                  7.831623  29.068514  30.722418  20.230850  87.853405

# %%
print(data["Rango endeudamiento"].value_counts())
print(data["PRODUCTO"].value_counts())
print(data["REGION"].value_counts())
# Out:
# 1 a 15       41777
# <1M          18485
# 15 a 50      14248
# 50 a 100      2950
# 100 a 200      594
# >200           190
# Name: Rango endeudamiento, dtype: int64
# TARJETAS DE CREDITO    50846
# CONSUMO                19294
# VEHICULOS SUFI          5514
# MASIVO SUFI             2589
# CH PROPIA                  1
# Name: PRODUCTO, dtype: int64
# BOGOTA       23537
# ANTIOQUIA    15907
# CENTRO       13935
# SUR          13235
# CARIBE       11630
# Name: REGION, dtype: int64

# %%
data["PRODUCTO"].value_counts()
# Out:
# TARJETAS DE CREDITO    50846
# CONSUMO                19294
# VEHICULOS SUFI          5514
# MASIVO SUFI             2589
# CH PROPIA                  1
# Name: PRODUCTO, dtype: int64

# %%
pd.crosstab(data['Abogado'], data["PRODUCTO"], margins=True)/89062*100
# Out:
# PRODUCTO  CH PROPIA    CONSUMO  MASIVO SUFI  TARJETAS DE CREDITO  \
# Abogado
# 109970     0.000000   1.788642     0.028070             0.072983
# 109971     0.000000   0.005614     0.011228             0.165054
# 109976     0.000000   3.724372     0.321125             5.483820
# 109978     0.001123  16.144933     2.546541            51.368709
# All        0.001123  21.663560     2.906964            57.090566
#
# PRODUCTO  VEHICULOS SUFI        All
# Abogado
# 109970          0.000000   1.889695
# 109971          0.000000   0.181896
# 109976          0.798320  10.327637
# 109978          5.392872  75.454178
# All             6.191193  87.853405

# %%
endeudamiento_cuadrante=data.groupby(["Abogado", "Calificacion Real"]).aggregate({"Calificacion Real":"count", "Valor Obligacion":"count"})
endeudamiento_cuadrante.rename(columns=({"Calificacion Real":"Conteo Productos"}), inplace=True)
endeudamiento_cuadrante.reset_index(inplace=True)
sns.barplot(endeudamiento_cuadrante, x="Abogado", y="Valor Obligacion", hue="Calificacion Real")
# Out:
# <Axes: xlabel='Abogado', ylabel='Valor Obligacion'>

# %%
pd.crosstab(data['Abogado'], data["Cuadrante"], margins=True)/89062*100
# Out:
# Cuadrante  NO TIENE VOLUNTAD Y NO TIENE CAPACIDAD  \
# Abogado
# 109970                                   0.000000
# 109971                                   0.000000
# 109976                                   0.002246
# 109978                                   0.059509
# All                                      0.061755
#
# Cuadrante  NO TIENE VOLUNTAD Y TIENE CAPACIDAD  SIN CUADRANTE  \
# Abogado
# 109970                                0.135860       0.980216
# 109971                                0.026948       0.046035
# 109976                                1.100357       1.047585
# 109978                                4.411534      21.252611
# All                                   5.674699      23.326447
#
# Cuadrante  TIENE VOLUNTAD Y NO TIENE CAPACIDAD  \
# Abogado
# 109970                                0.005614
# 109971                                0.000000
# 109976                                0.238036
# 109978                                0.342458
# All                                   0.586109
#
# Cuadrante  TIENE VOLUNTAD Y TIENE CAPACIDAD  \
# Abogado
# 109970                             0.123509
# 109971                             0.023579
# 109976                             1.524780
# 109978                            25.103860
# All                               26.775729
#
# Cuadrante  TIENE VOLUNTAD Y TIENE CAPACIDAD REDUCIDA        All
# Abogado
# 109970                                      0.644495   1.889695
# 109971                                      0.085334   0.181896
# 109976                                      6.414633  10.327637
# 109978                                     24.284207  75.454178
# All                                        31.428668  87.853405

# %%
my_report=sv.analyze(V_num)
my_report.show_html()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
my_report.show_notebook()
# Out:
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# !function(e,t){&quot;use strict&quot;;&quot;object&quot;==typeof module&amp;&amp;&quot;object&quot;==typeof module.exports?module.exports=e.document?t(e,!0):function(e){if(!e.document)throw new Error(&quot;jQuery requires a window with a document&quot;);return t(e)}:t(e)}(&quot;undefined&quot;!=typeof window?window:this,function(C,e){&quot;use strict&quot;;var t=[],E=C.document,r=Object.getPrototypeOf,s=t.slice,g=t.concat,u=t.push,i=t.indexOf,n={},o=n.toString,v=n.hasOwnProperty,a=v.toString,l=a.call(Object),y={},m=function(e){return&quot;function&quot;==typeof e&amp;&amp;&quot;number&quot;!=typeof e.nodeType},x=function(e){return null!=e&amp;&amp;e===e.window},c={type:!0,src:!0,nonce:!0,noModule:!0};function b(e,t,n){var r,i,o=(n=n||E).createElement(&quot;script&quot;);if(o.text=e,t)for(r in c)(i=t[r]||t.getAttribute&amp;&amp;t.getAttribute(r))&amp;&amp;o.setAttribute(r,i);n.head.appendChild(o).parentNode.removeChild(o)}function w(e){return null==e?e+&quot;&quot;:&quot;object&quot;==typeof e||&quot;function&quot;==typeof e?n[o.call(e)]||&quot;object&quot;:typeof e}var f=&quot;3.4.1&quot;,k=function(e,t){return new k.fn.init(e,t)},p=/^[\s\uFEFF\xA0]+|[\s\uFEFF\xA0]+$/g;function d(e){var t=!!e&amp;&amp;&quot;length&quot;in e&amp;&amp;e.length,n=w(e);return!m(e)&amp;&amp;!x(e)&amp;&amp;(&quot;array&quot;===n||0===t||&quot;number&quot;==typeof t&amp;&amp;0&lt;t&amp;&amp;t-1 in e)}k.fn=k.prototype={jquery:f,constructor:k,length:0,toArray:function(){return s.call(this)},get:function(e){return null==e?s.call(this):e&lt;0?this[e+this.length]:this[e]},pushStack:function(e){var t=k.merge(this.constructor(),e);return t.prevObject=this,t},each:function(e){return k.each(this,e)},map:function(n){return this.pushStack(k.map(this,function(e,t){return n.call(e,t,e)}))},slice:function(){return this.pushStack(s.apply(this,arguments))},first:function(){return this.eq(0)},last:function(){return this.eq(-1)},eq:function(e){var t=this.length,n=+e+(e&lt;0?t:0);return this.pushStack(0&lt;=n&amp;&amp;n&lt;t?[this[n]]:[])},end:function(){return this.prevObject||this.constructor()},push:u,sort:t.sort,splice:t.splice},k.extend=k.fn.extend=function(){var e,t,n,r,i,o,a=arguments[0]||{},s=1,u=arguments.length,l=!1;for(&quot;boolean&quot;==typeof a&amp;&amp;(l=a,a=arguments[s]||{},s++),&quot;object&quot;==typeof a||m(a)||(a={}),s===u&amp;&amp;(a=this,s--);s&lt;u;s++)if(null!=(e=arguments[s]))for(t in e)r=e[t],&quot;__proto__&quot;!==t&amp;&amp;a!==r&amp;&amp;(l&amp;&amp;r&amp;&amp;(k.isPlainObject(r)||(i=Array.isArray(r)))?(n=a[t],o=i&amp;&amp;!Array.isArray(n)?[]:i||k.isPlainObject(n)?n:{},i=!1,a[t]=k.extend(l,o,r)):void 0!==r&amp;&amp;(a[t]=r));return a},k.extend({expando:&quot;jQuery&quot;+(f+Math.random()).replace(/\D/g,&quot;&quot;),isReady:!0,error:function(e){throw new Error(e)},noop:function(){},isPlainObject:function(e){var t,n;return!(!e||&quot;[object Object]&quot;!==o.call(e))&amp;&amp;(!(t=r(e))||&quot;function&quot;==typeof(n=v.call(t,&quot;constructor&quot;)&amp;&amp;t.constructor)&amp;&amp;a.call(n)===l)},isEmptyObject:function(e){var t;for(t in e)return!1;return!0},globalEval:function(e,t){b(e,{nonce:t&amp;&amp;t.nonce})},each:function(e,t){var n,r=0;if(d(e)){for(n=e.length;r&lt;n;r++)if(!1===t.call(e[r],r,e[r]))break}else for(r in e)if(!1===t.call(e[r],r,e[r]))break;return e},trim:function(e){return null==e?&quot;&quot;:(e+&quot;&quot;).replace(p,&quot;&quot;)},makeArray:function(e,t){var n=t||[];return null!=e&amp;&amp;(d(Object(e))?k.merge(n,&quot;string&quot;==typeof e?[e]:e):u.call(n,e)),n},inArray:function(e,t,n){return null==t?-1:i.call(t,e,n)},merge:function(e,t){for(var n=+t.length,r=0,i=e.length;r&lt;n;r++)e[i++]=t[r];return e.length=i,e},grep:function(e,t,n){for(var r=[],i=0,o=e.length,a=!n;i&lt;o;i++)!t(e[i],i)!==a&amp;&amp;r.push(e[i]);return r},map:function(e,t,n){var r,i,o=0,a=[];if(d(e))for(r=e.length;o&lt;r;o++)null!=(i=t(e[o],o,n))&amp;&amp;a.push(i);else for(o in e)null!=(i=t(e[o],o,n))&amp;&amp;a.push(i);return g.apply([] ...

# %%
plt.figure(figsize=(16, 6))  # Ajusta el tamaño de la figura

# Gráfico de caja
plt.subplot(1, 2, 1)  # Subplot 1 de 2 columnas
sns.boxplot(data=V_num, orient="h", palette="Set2")
plt.title("Gráfico de Caja para Variables Numéricas")
plt.xlabel("Valor")



plt.tight_layout()
plt.show()

# %%
# Calcular el rango intercuartil (IQR) para cada columna
Q1 = V_num.quantile(0.25)
Q3 = V_num.quantile(0.75)
IQR = Q3 - Q1

# Definir los límites para valores atípicos
limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR
# Encontrar valores atípicos en cada columna
valores_atipicos = ((V_num < limite_inferior) | (V_num > limite_superior)).any(axis=1)

# Filtrar las filas con valores atípicos
filas_con_valores_atipicos = V_num[valores_atipicos]

# Imprimir las filas con valores atípicos
print(filas_con_valores_atipicos)
# Out:
#        Valor Obligacion  Endeudamiento  Valor Vencido  Dias Mora
# 1               40584.0       40584.00        40584.0        110
# 3             5904653.0     5904653.00      1455631.0         90
# 4             2221125.0     2221125.00      2221125.0         48
# 6             1527464.0     1574242.00      1527464.0         60
# 12             874684.0      874684.00       874684.0        120
# ...                 ...            ...            ...        ...
# 89242         2048599.0    37088351.03       284377.0         95
# 89243        33835903.0    45757681.00      2790040.0        104
# 89244         1540300.0    45757681.00      1511822.0        107
# 89245         3954718.0    45757681.00       609495.0        107
# 89246         2172488.0    45757681.00       350295.0        107
#
# [27182 rows x 4 columns]

# %%
limite_superior
# Out:
# Valor Obligacion    13383057.75
# Endeudamiento       40497104.25
# Valor Vencido        1371839.25
# Dias Mora                 76.00
# dtype: float64

# %%
V_num
# Out:
#        Valor Obligacion  Endeudamiento  Valor Vencido  Dias Mora
# 0             5637605.0     5637605.00       152093.0         30
# 1               40584.0       40584.00        40584.0        110
# 2             2786178.0     7747280.00       547088.0         60
# 3             5904653.0     5904653.00      1455631.0         90
# 4             2221125.0     2221125.00      2221125.0         48
# ...                 ...            ...            ...        ...
# 89242         2048599.0    37088351.03       284377.0         95
# 89243        33835903.0    45757681.00      2790040.0        104
# 89244         1540300.0    45757681.00      1511822.0        107
# 89245         3954718.0    45757681.00       609495.0        107
# 89246         2172488.0    45757681.00       350295.0        107
#
# [89247 rows x 4 columns]

# %%
for var in V_num.columns:
  # Calcular el rango intercuartil (IQR) para cada columna
  Q1 = data[var].quantile(0.25)
  Q3 = data[var].quantile(0.75)
  IQR = Q3 - Q1

  # Definir los límites para valores atípicos
  limite_inferior = Q1 - 1.5 * IQR
  limite_superior = Q3 + 1.5 * IQR
  data[f'atipico_{var}'] = np.where(data[var] < limite_inferior, 1, 0)
  data.loc[(data[var] > limite_superior), f'atipico_{var}'] = 1

# %%
data.head()
# Out:
#    Consecutivo Documento Deudor  Nit  Nombres  Numero Documento  \
# 0                      28768192   18      NaN               NaN
# 1                       2712044   22      NaN               NaN
# 2                      13587837   23      NaN               NaN
# 3                      23479925   46      NaN               NaN
# 4                       2712382   92      NaN               NaN
#
#    Tipo De Producto             PRODUCTO  Valor Obligacion  Valor Vencido  \
# 0                 3  TARJETAS DE CREDITO         5637605.0       152093.0
# 1                 5              CONSUMO           40584.0        40584.0
# 2                 3  TARJETAS DE CREDITO         2786178.0       547088.0
# 3                 3  TARJETAS DE CREDITO         5904653.0      1455631.0
# 4                 5              CONSUMO         2221125.0      2221125.0
#
#    Regional  REGION  ...  Fecha De Perfeccionamiento  Endeudamiento  \
# 0      2099  BOGOTA  ...                  1978-12-06      5637605.0
# 1      2099  BOGOTA  ...                  2015-03-11        40584.0
# 2      3099     SUR  ...                  2003-03-27      7747280.0
# 3      2099  BOGOTA  ...                  1990-09-01      5904653.0
# 4      6399  CENTRO  ...                  2015-05-12      2221125.0
#
#   Rango endeudamiento Sector Economico      Profesion   Ocupacion  \
# 0              1 a 15              NaN  SIN PROFESION  SIN OFICIO
# 1                 <1M              NaN  SIN PROFESION  SIN OFICIO
# 2              1 a 15              NaN  SIN PROFESION    JUBILADO
# 3              1 a 15              NaN  SIN PROFESION  SIN OFICIO
# 4              1 a 15     AGROPECUARIO     AGRICULTOR     TAXISTA
#
#    atipico_Valor Obligacion  atipico_Endeudamiento atipico_Valor Vencido  \
# 0                         0                      0                     0
# 1                         0                      0                     0
# 2                         0                      0                     0
# 3                         0                      0                     1
# 4                         0                      0                     1
#
#   atipico_Dias Mora
# 0                 0
# 1                 1
# 2                 0
# 3                 1
# 4                 0
#
# [5 rows x 31 columns]

# %%
from seaborn.axisgrid import pairplot
pairplot(V_num)

# %%
data['Dias Mora'].describe()
# Out:
# count    89247.000000
# mean        47.099320
# std         70.105525
# min          1.000000
# 25%         26.000000
# 50%         30.000000
# 75%         46.000000
# max       2175.000000
# Name: Dias Mora, dtype: float64

# %%
data['Valor Obligacion'].describe()
# Out:
# count    7.824400e+04
# mean     4.424137e+06
# std      9.314002e+06
# min      1.804400e+04
# 25%      6.864612e+05
# 50%      1.604043e+06
# 75%      3.929639e+06
# max      4.894150e+08
# Name: Valor Obligacion, dtype: float64

# %%
plt.boxplot(data['Valor Obligacion'])

# %%
plt.boxplot(data['Dias Mora'])

# %%
## se elimina columna region ya que en el codigo "regional" la columba region se encuentra implicito y evitar problemas de multicolinealidad

data.drop(columns="REGION", axis=1, inplace=True)

# %%
data["Descripcion Causal"].value_counts()
#que hacer con un desbalance de datos tan grande?

# %%
# Especificamos tamaño de la figura
plt.figure(figsize=(20,10))

#Ejecutamos la correlación entre las variables
correlacion = data.corr()

#Gráfica de correlación heatmap

mask = np.triu(np.ones_like(correlacion, dtype=np.bool))
heatmap = sns.heatmap(correlacion, mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Gráfico de correlación', fontdict={'fontsize':18}, pad=16);

# %%
print(data.dtypes)

# %%
PRODUCTO = pd.get_dummies(data['PRODUCTO'],drop_first=True) ## por que es el drop first?

# %%
FRANJA = pd.get_dummies(data['FRANJA'],drop_first=True)

# %%
Segmento = pd.get_dummies(data['Segmento'],drop_first=True)

# %%
Cuadrante = pd.get_dummies(data['Cuadrante'],drop_first=True)

# %%
Descripcion_Causal = pd.get_dummies(data['Descripcion Causal'],drop_first=True)

# %%
#eliminamos las columnas de las que obtuvimos las dummies

# %%
data.drop(['PRODUCTO','FRANJA','Segmento','Cuadrante','Descripcion Causal',],axis=1,inplace=True)

# %%
data.dtypes

# %%
data["Fecha De Perfeccionamiento"]=data["Fecha De Perfeccionamiento"].dt.month

# %%
data[data["Nit"].duplicated()]

# %%
data1 = pd.concat([data,PRODUCTO,FRANJA,Segmento,Cuadrante,Descripcion_Causal,],axis=1)## nuevo dataset con dummies

# %%
X = list(Train.columns)
Y = list(filter(lambda t: t not in ['Attrition'], m))
